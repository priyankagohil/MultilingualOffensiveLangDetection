# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 4.9 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.8 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 61.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 48.9 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 53.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d91ecf6751f197afa9840cc893f8214a0f75df0b0300f7f02879a18b27921160
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 sacremoses-0.0.53 tokenizers-0.12.1 transformers-4.18.0

# %%
# !python /content/drive/MyDrive/src/bert_finetuned/bert_finetune_OLID_error_analysis.py \
--language 'greek' \
--ckpt_loc '/content/drive/MyDrive/src/bert_finetuned/ckpts/greek/bert_greek.pth' --subtask 'subtask_a'
# Out:
# Downloading: 100% 2.00/2.00 [00:00<00:00, 2.19kB/s]
# Downloading: 100% 459/459 [00:00<00:00, 407kB/s]
# Downloading: 100% 518k/518k [00:00<00:00, 5.66MB/s]
# Downloading: 100% 112/112 [00:00<00:00, 98.3kB/s]
# Downloading: 100% 433M/433M [00:12<00:00, 36.7MB/s]
# Some weights of the model checkpoint at nlpaueb/bert-base-greek-uncased-v1 were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at nlpaueb/bert-base-greek-uncased-v1 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /content/drive/MyDrive/data1/
# true label: NOT	 pred_label: OFF	 tweet: @USER Η μόνη που πήρε τον πουλο γλυκιά μου είσαι εσυ . Ρουφα τώρα ως τις εκλογες... #ηρθε_και_ηταν_μεγαλη
# true label: OFF	 pred_label: NOT	 tweet: Καλα τα ειπε ρε μαλακες ο Τσιπρας. Εγω πχ δεν πηγαινω κουβα. Το προβλημα ειναι οτι αυξανονται τα λεφτα που χανω αλλα μενουν σταθερα αυτα που δινω
# true label: NOT	 pred_label: OFF	 tweet: Κουράδες που νομίζουν ότι είναι κάτι και βρίζουν μάνες, έχουμε και από αυτά τα σκουπίδια. Πάνε ψόφα ρε κακομοίρη.
# true label: OFF	 pred_label: NOT	 tweet: @USER Α εσύ είσαι ντιπ για ντιπ
# true label: NOT	 pred_label: OFF	 tweet: Δεν τελειώσαμε FF σκουπιδιαρες, ρακοσυλλεκτριες θα σας δικασω και αύριο #gntm #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: @USER Δεν πιστεβω λεξη απο οσα λες! Εισαι προδοτης απατεωνας! Δεν εισαι Ελληνας! Να θυμασε ο θεος συνχωρει η Μακεδονες οχι! Αν εισουν ανδρας με παντελονια δε θα εβαζες τους Συριζομπατσουσου να σε φυλανε Κουμουνι μισελληνα! Αλλα πιος εχασε τον ανδρισμο του για να τον βρεις εσυ Τουρκαλα!
# true label: OFF	 pred_label: NOT	 tweet: @USER Εννοεις οτι ο Αναστοπουλος κληρωθηκε στο ματς με Προμηθεα;Ειλικρινα πιστευεις τετοιο πραγμα;Μια ομαδα το απαιτει απο τοτε που σφυριζουν μονιμως οι ιδιοι Ελληνες εδω κ τοσα χρονια με τους οποιους εχει θεμα.Να εισαι μαγκας να παιξεις με ξενους.. που το προβλημα;Μηδεν μουρμουρα μετα
# true label: NOT	 pred_label: OFF	 tweet: Το πλατό Του πλατου Κάτια ξινομουνα 2019 μ.Χ #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: Μαρτινα κοιτα το μνι σου το χτυπημένο κ μη μιλας! #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: Δεν έμαθες ούτε από τον Εφιάλτη ούτε από τον Ιούδα. Γιατί τέτοιου βεληνεκούς ρουφιάνος είσαι. Κρίμα.
# true label: NOT	 pred_label: OFF	 tweet: Όσοι δεν μπήκατε στο ZMAKDOME WORLD INVASION χάσατε τον πιο υπέρτατο κώλο που έχει πατήσει σε Ελληνικό pro-wrestling ring. Και με αυτό εννοώ ότι ήταν τυχεροί οι ξένοι γιατί μας πήραν δυο ζώνες. Αυτό εννοώ με αυτό. Με αυτό, αυτό εννοώ.
# true label: NOT	 pred_label: OFF	 tweet: Η Λουκά των Ζαίων. Ατέλειωτα ρε πούστη μου είναι τα ληγμένα στο Σύριζα; #ερχεται_ΠΟΥΤΣΑ #ερχεται_ΚΑΡΑΠΟΥΤΣΑ
# true label: NOT	 pred_label: OFF	 tweet: Αυτή τη πουταναρα τη Ρεγγινα γιατί την κρατάτε;Για να κάνετε νούμερα με το νούμερο;Σε όλα τα παιδιά μια συμβουλή Μακριά από αυτήν είναι ξεφτίλα και έχει μπει στην κλιμακτήριο......Γι αυτό συμπεριφέρεται έτσι #poweroflovegr
# true label: NOT	 pred_label: OFF	 tweet: @USER Ο κόσμος προχώραει ρε γίδι. Αλλά και τότε φασιστας θα ήταν απλά δεν υπήρχε η ορολογία ορνιο. Και η Αμερική πριν 550 χρόνια πήρε το όνομά της αλλά υπήρχε και πριν ανακαλυφθεί.
# true label: NOT	 pred_label: OFF	 tweet: @USER Για το Ρασπούτιν μιλάμε ; Παλιό...με αχαλίνωτες ακολασίας μασκοφορεμένες από τα κο μούνια !
# true label: OFF	 pred_label: NOT	 tweet: Δεν ξέρει ο μπαρμπα Γιώργης στο χωριό ούτε για φυσικά δικαιώματα, ούτε για κρατική καταπίεση, ούτε τπτ. Αλλά ξέρει ότι είναι άδικο και καταπιεστικό να του φέρνετε με το έτσι θέλω εποίκους! Οπότε θα γίνει και φασίστας, αφού δεν ξέρει άλλο τροπο να αντιδράσει. #μεταναστευτικο
# true label: NOT	 pred_label: OFF	 tweet: «Ναι, εννοείται, ότι ο Βενιζέλος πάντα θα ακούγεται όπως μία καμπάνα που βρίσκεται έστω και μακριά» Κώστας Γιαννακίδης Ναι, έχει σήμα πουτάνα.
# true label: NOT	 pred_label: OFF	 tweet: Η μάνα της Μαρτινας αντί να μαλώνει με την Σούλα στο ινστα ας δει τι φίδι μεγαλώνει καλύτερα δικό της αποτέλεσμα είναι τούτο το έκτρωμα κοπελιά άνοιξε τα σχόλια στο ινστα εφόσον είσαι τόσο εντάξει και τσαμπουκας και κακο σκυλί και μπλα μπλα μπλα #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: @USER δεν εχει να κανει με Μπακογιαννη.οτι μη δεξιο κινειται στο τουιτερ θα στοχευεται απο εδω και περα για καποιο διαστημα.βαζουν φυτιλιες οι "ξυπνιοι" αλλα ως ξυπνιοι στελνουν τα τελειως ζαβα για πεσιμο και αστα..25χιλιαδες τουη τωρα μας εχουν κλασει τα αρχιδια.
# true label: NOT	 pred_label: OFF	 tweet: @USER ΜΕΧΡΙ ΚΑΙ ΟΙ ΑΤΑΡΤΕΣ ΦΛΩΡΕΨΑΝ.ΑΝΤΙ ΝΑ ΠΑΡΕΙΣ ΑΠΟΣΜΗΤΙΚΟ ΧΩΡΟΥ ΜΕ ΓΙΔΙΑ ΠΟΥ ΓΑΜΙΟΥΝΤΑΙ ΚΑΙ ΕΣΑΝΣ ΦΑΣΟΛΑΔΑΖ ΤΟ ΕΧΕΙΣ ΡΙΞΕΙ ΣΤΑ ΠΑΚΟ ΡΑΠΑΝ ΚΑΙ ΣΤΑ ΒΕΡΤΣΑΤΣΕ. ΨΟΦΟ ΥΓΡΟ ΚΑΙ ΟΔΥΝΗΡΟ ΠΡΟΣΚΥΝΗΜΕΝΕ. ΒΑΘΙΑ ΨΥΧΗ
# true label: NOT	 pred_label: OFF	 tweet: @USER Μιλάς εσυ ο Μίκυ Μαους για γελοιότητες ; Ούτε καν το θάρρος να μιλας χώρις να κρύβεσαι δεν έχεις ... ένα άβουλο ηλιθιο παπαγαλάκι που πληρώνεσε να καλύπτεις τον κάθε αλήτη και αχρειο , μέλος του βρωμικου συστήματος είσαι ηλίθιε
# true label: OFF	 pred_label: NOT	 tweet: Α μαλακες μην ξεχάσω. Έχετε κολλήσει με γκομενέτο και υποφέρετε αλλά για οποιοδήποτε λόγο θέλετε να απεμπλακειτε από τα δίχτυα του έρωτα και να ησυχάσετε; Για τσεκάρετε τον πρώην της. Υπάρχει σοβαρό ενδεχόμενο να γλιτώσετε.
# true label: OFF	 pred_label: NOT	 tweet: Ασημίνα πότε φεύγεις μωρή #GNTMgr
# true label: NOT	 pred_label: OFF	 tweet: @USER Βουλωστο μπούλη εσύ είσαι μπουκωμένος μέχρι το λαρύγγι τσογλαν τσιμπουκ χαχαχα
# true label: NOT	 pred_label: OFF	 tweet: Το έφτιαξα μόνη μου το καζανακι να πάτε να γαμηθειτε όλοι και κυρίως οι αντρες
# true label: OFF	 pred_label: NOT	 tweet: Άνοιξα τον λογαριασμό της ΔΕΗ. Χωρίς έκπτωση του ..συνεπή καταναλωτή.. Πενήντα ευρώ πάνω..Κουλη μου θελατε γιδια..Το ιδιο εύχομαι και σε σας..Αει σιχτιρ..
# true label: OFF	 pred_label: NOT	 tweet: @USER Ρεζιλι εχεις γινει ρε φιλε!Σοβαρα δεν σκεφτεσαι τα παιδια σου που μπορει να διαβαζουν απο κατω τα σχολια και σε βριζουν;Και ολα αυτα γιατι;Γιατι χασατε και θα πατε στο διαολο!Χωνεψε το και ζησε με αυτο!
# true label: NOT	 pred_label: OFF	 tweet: Ηλίθια ακροδεξιά κνώδαλα, πηγαίνετε στην όμορφη Κυψέλη, που ζουν τα τελευταία χρόνια 2 με 3 χιλιάδες πρόσφυγες, κυρίως από την Συρία, να δείτε κοπέλες με μαντήλες μαζί με τα αγόρια τους να πίνουν δροσερή βαρελίσια και να τρώνε ζουμερά καλαμάκια με μπόλικο λεμόνι. Ηλίθιοι.
# true label: NOT	 pred_label: OFF	 tweet: @USER Ακόμη εδώ είσαι, μαρξιστοειδές; Να γράψεις 100 φορές "τιμώ και σέβομαι τους αγώνες της Αριστεράς" και να ξαναδιαβάσεις την "Λίστα Σεβασμού Αριστερών Αγώνων" που τηρείται στο παραμάγαζό σας. Άιντε, Δεξιοί από το Praktiker, που θέλετε να μιλήσετε κιόλας. Άσχετοι κομμουνιστολάγνοι.
# true label: NOT	 pred_label: OFF	 tweet: Γαμιωλες FF! Νομίζετε οτι θα κάνετε καριέρα; Με τετοιο χαρακτήρα κάνεις δε θα σας πάρει #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: #shoppingstar τά είδαμε τά νύχια πονηρούλι..
# true label: OFF	 pred_label: NOT	 tweet: @USER Οι απειλές και οι ύβρεις είναι φυσικά απαράδεκτες, όπως και η ιδεολογική τρομοκρατία να χαρακτηρίζεται "φασίστας" και "ρατσιστής" όποιος αντιδρά στον επιδοτούμενο εποικισμό.
# true label: NOT	 pred_label: OFF	 tweet: @USER Ξέρει όμως ότι είσαι γλιτσας Κάτι είναι κι αυτό
# true label: NOT	 pred_label: OFF	 tweet: Εν τω μεταξυ μαλακια της της Τουμασατου. Τωρα θα μπλεξει το Μαρινιω. #GynaikaXwrisOnoma
# true label: NOT	 pred_label: OFF	 tweet: Θα την φανε την κουτουλια με τα κερατα και θα τους γινει το αιδοίο κόσκινο #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: @USER κυρ Απόστολε το έχουμε χάσει το παιχνίδι. Οι λευκές γυναίκες γουστάρουν να πηδιούνται με μαύρους. Θυμήσου τη μάνα του Obama που παντρεύτηκε τον Κενυάτη, την παράτησε σε δύο χρόνια και μετά ξαναπαντρεύτηκε έναν ασιάτη που την έδερνε
# true label: OFF	 pred_label: NOT	 tweet: ρε βικυ τι μαλακιες λες...η κοπελα ηθελε ενα φορεμα για βραδυ...ουτε το θεμα δεν ελεγε...καταλαβαμε αυτη θα βγαλεις νικητρια... #shoppingstar
# true label: NOT	 pred_label: OFF	 tweet: @USER Και που ξέρεις ρε μαλακά αν η κάθε νεα κοπέλα θέλει να γίνει μάνα; γενικά να παντρευτεί και να έχει τον κάθε προβληματικό σαν κ εσένα πάνω από το κεφάλι της; βασικά δν παίζει νάσαι τόσο μαλακάς
# true label: OFF	 pred_label: NOT	 tweet: Ρε μαλακες
# true label: OFF	 pred_label: NOT	 tweet: Αφου σου μιλανε μωρη και το αρνεισαι αυτο που σου λενε!#GNTMgr
# true label: NOT	 pred_label: OFF	 tweet: Τωρα που έπρεπε να βάλετε διπλό βάζετε ένα επεισόδιο. Αναποδος χρονος 13 μηνες ειστε ρε πουστη μου. #erwtasmeta
# true label: NOT	 pred_label: OFF	 tweet: Τι είπε το σίχαμα ο Κυριάκος πάλι! Εεεε τότε τι πηγές ρε οικογενειάρχη κ παρατήσεις το παιδί σου! Για να σε βλέπουν να παίζεις τάβλι #SurvivorGr
# true label: NOT	 pred_label: OFF	 tweet: Όχι γμτ δεν έφυγε η βλαμμενη #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: Νικητρια η Χαρα. Παρτα μωρη Κατια-καρχια #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: Μαδομούνι από τα Lidl #gntmGR
# true label: OFF	 pred_label: NOT	 tweet: Μαλάκα πολύ αληθινό αυτό το #kokkinopotami , έ;
# true label: NOT	 pred_label: OFF	 tweet: Λυπάμαι τους άντρες που πληρώνουν τις εξόδους για να πηδήξουν αυτό το πράγμα #shoppingstar
# true label: NOT	 pred_label: OFF	 tweet: @USER αυτό το «περνάω τέλεια» μου θυμίζει τους συμμετέχοντες σε ριάλιτι που λένε «ήταν η πιο ωραία εμπειρία της ζωής μου» και με θλίβει που οι ζωές τους είναι τόσο σκατά. Σκέψου πως είναι να είσαι ο Ουγγαρέζος μλκ μου
# true label: NOT	 pred_label: OFF	 tweet: @USER 17νοεβρη ,πυρηνες της πουστιας , αναρχο-πουστρονια , εξαρχια , ρωμανοι , μπουφοντινες , ρουβικωνες ΟΛΟΙ.... Φασιστες ! Μονο εσυ εισαι σκατοκουΜΟΥΝΙ Λοβερδο μπαγλαμα...να καλυψεις την "μητρα" που σε εφερε στην πολιτικη θελεις , αλλα ΔΕΝ γινεται Η αριστερα γεναει δολοφονους
# true label: NOT	 pred_label: OFF	 tweet: Λοιπόν βρήκα τι πρέπει να έχει μέσα μια σειρά για να αρέσει. Κακιασμένες γκομενιτσες, σκύλες και τσόλια, ηλίθιες και χαζοβιόλες. Κάτι σαν το #GNTMgr αλλά με πλοκή.
# true label: OFF	 pred_label: NOT	 tweet: Αυτό το ζευγάρι έτσι λειτουργεί, δεν ήξεραν να πάρουν την άδεια σας και μας για το πως θα λειτουργούν.... Για να είναι χρόνια μαζί σημαίνει πως ΓΟΥΣΤΆΡΟΥΝ ΑΥΤΌ ΠΟΥ ΕΙΝΑΙ! ΥΓ: ο Πάριος σιγά μην δεν είναι περήφανος για την οικογένεια του παιδιού του... ΗΛΊΘΙΟΙ! #mesimeri_skai
# true label: NOT	 pred_label: OFF	 tweet: Στυλιστρια της δεκάρας να σου πω πως η Πάρις έχει καλύτερο κωλο από τον δικό σου, οπότε βουλωνε #shoppingstar
# true label: NOT	 pred_label: OFF	 tweet: Φιρι-φιρι το παει να χασει. @USER εισαι πολυ κωλοφαρδος λεμε.
# true label: NOT	 pred_label: OFF	 tweet: @USER Περιμενεις να σε πουν μπραβο για το πενταευρο και υπερηφανευεσαι κιολας, μα ποσο μαλακοπιτουρας μπορει να εισαι;
# true label: NOT	 pred_label: OFF	 tweet: Παραιτήθηκε ο Παναγιώτης Λαφαζάνης από την ηγεσία της ΛΑΕ. Στο διάολο λοιπόν και ακόμα παραπέρα/ ΥΓ Ένα πολιτικό απολίθωμα λιγότερο για αυτήν την ταλαίπωρη χώρα. ΥΓ Μετά της 7-7-2019 παίρνει σειρά και ο Λαοπρόβλητος, τρόμπας.
# true label: NOT	 pred_label: OFF	 tweet: Το ρίχνεις δεξιά, αποδεξιά, νεοδεξιά, πασοκοδεξιά ΟΚ! Ντάξει στην καλύτερη είσαι κολλημένος, στη χειρότερη είσαι κάγκουρας. Αν το ρίξεις όμως στους ναζί ΕΙΣΑΙ ΚΙ ΕΣΥ ΔΟΛΟΦΟΝΟΣ!
# true label: NOT	 pred_label: OFF	 tweet: @USER Μπορείτε ν τους πάρετε όλους στην Κρήτη κ μαζί κ τους ψυχοπονιαρηδες αλληλέγγύους που τους θέλουν κ επίσης κ τους πουστήδες που θα τους χρειαστούν οι λαθρομετανάστες για να έχουν κάποιον να σπρώχνουν όταν θα νοιώθουν μοναξιές το βράδυ, ευκαιρία ν ξεσαβουριασει η υπόλοιπη Ελλάδα
# true label: OFF	 pred_label: NOT	 tweet: @USER Και τον βεργη καποιοι παλαβοι ψηφισανε την στιγμη που ο αλλος θελει να τον ψηφισει δε μπορουμε να πουμε οτι εισαι λαθος που τον ψηφιζεις απλα πως διαφωνουμε με την ψηφο σου
# true label: NOT	 pred_label: OFF	 tweet: @USER ηλίθιο τρολακι roof το έχεις χάσει Εδώ mardou mother Δημάδη Είσαι πολύ Μ...ας ακόμα κι σε αυτό το απλό έξω πέφτεις διαδίδοντας fake news Σκέψου πόσο μένος έχεις για Σουλτογιαννη και Δημάδη Η ηλιθιότητα και η κακια ανίκητες κύριε η κυρία κλαρινογαμπρε-νυφη Ρωτά να μάθεις for me
# true label: NOT	 pred_label: OFF	 tweet: Τι σκατα , λάδι από ποντικοουρά έχουν μέσα αυτά τα cream n dust και βγάζουν όλες του πούστη τη λιπαρότητα; #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: @USER Έλα μωρή γαλοπούλα
# true label: NOT	 pred_label: OFF	 tweet: @USER Αφού τους είχες ζήσει, όπως και γω, φαντάσου πόσο βλακας είσαι που τόσο καιρό δεν είχες καταλάβει πως να μην σου ξανασυμβεί.
# true label: NOT	 pred_label: OFF	 tweet: «Μόνο εσυ υπάρχεις στην ζωή μου» λεει ο Ανδρέας. Άσε μας ρε φίλε, σε είδαμε κ εσένα το κουμασι εισαι #GynaikaXwrisOnoma
# true label: NOT	 pred_label: OFF	 tweet: Πω το επεισόδιο είναι όλο σάλια απόψε.... Εμετος.. #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: @USER Είσαι αστείος... Όσο για το από κοντά παλικαράκι της φακής, εγώ στην πλατεία είμαι αλλά δν τολμάτε μουνοπανα να έρθετε.. Γιαυτό οι ψευτομαγκες όχι σε μένα.. Έχετε και άποψη ζώα...
# true label: OFF	 pred_label: NOT	 tweet: Σκουλε πολύ το δειχνεις ότι η Κατια είναι βύσμα σου. Κατια τώρα που είδαν τον χαρακτήρα σου λες να δουλέψεις πολύ; #GNTMgr
# true label: OFF	 pred_label: NOT	 tweet: Τι έλεγε η άλλη όταν ψηφίζανε κ πουλουσανε την Μακεδονία;Δώστε πόνο; Πάρτε πουτσα τώρα #εκλογες2019 #ερχεται_ΠΟΥΤΣΑ
# true label: OFF	 pred_label: NOT	 tweet: Μωρή Ανέτ,με συγκινησες! #AgriesMelisses
# true label: NOT	 pred_label: OFF	 tweet: @USER Σαφώς και την αλλάζει και σου το λέει ένας άνθρωπος που δεν χρωστάει ούτε λεπτό στο δημόσιο αλλά στο τέλος κάθε χρονιάς νιώθω ο μαλάκας της παρέας όταν μπορώ να καταστήσω τα χρέη μου ληξιπρόθεσμα και να τα δώσω σε 120 δόσεις...
# true label: NOT	 pred_label: OFF	 tweet: Ενα βυζι εδω ενα βυζι εκει #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: @USER τι μουνόπανο είναι αυτό
# true label: OFF	 pred_label: NOT	 tweet: Εχω, για την ακρίβεια ειχα, ενα σωρο φιλους συριζαιους (και συγγενεις δυστυχως) και ξερω πολυ καλα για τι πραγμα μιλαω. Ειναι παντελως στ΄αρχιδια τους (σόρρι για την ωμοτητα) οι Μαδούροι, κι οι Μάηδες, και οι Τσε και ολα. Αυτα ειναι για τα γίδια, και στ΄αριστερά και στα...δεξιά.
# true label: OFF	 pred_label: NOT	 tweet: Έχω κάνει και 'γω διατροφή, αλλά στις ρυζογκοφρέτες δεν έπεσα ρε μαλάκες.
# true label: NOT	 pred_label: OFF	 tweet: Αστερι Μισελίν είπε η αμόρφωτη βλάχα; #masterchefgr_xeftiles
# true label: NOT	 pred_label: OFF	 tweet: @USER #ερχεται_πουτσα στα σπερματοζωάρια θα κολλήσουμε κυρ Σταυρακα ;
# true label: NOT	 pred_label: OFF	 tweet: @USER Εσένα πάντως σε βλέπω μάλλον με πληρωμει να πηδας γιατί αφού ούτε φωτογραφία δεν έχεις φαντάζομαι πώς θα είσαι πλιαχ
# true label: NOT	 pred_label: OFF	 tweet: Ο άλλος στο Μέτσοβο ονόμασε την ταβερνα - τα 5φ : φίλε φάγε φέρε, φίλους, φύγε. Εγώ θέλω να φτιάξω μια ταμπέλα για όλους κ όλα- τα 5γ: γαμιέστε, γαμιέστε, γαμιέστε, γαμιέστε, γαμιέστε.
# true label: NOT	 pred_label: OFF	 tweet: Φακινγκ Φούλς είστε ηλιθιες! Αυτό σας ταιριάζει άψογα! #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: Που ζουμε ρε μαλακα. Τι εχει συμβει στην ανθρωποτητα. HuffPost Greece: Βαρκελώνη: Πέντε άντρες βίασαν κορίτσι 14 ετών και αθωώθηκαν επειδή ήταν αναίσθητη. μέσω @USER
# true label: NOT	 pred_label: OFF	 tweet: @USER Έχει, λέει, 3 κόρες αν δεν είναι 4ποδες κι είναι δίποδες που είναι κ πολύ πιθανόν, ο άνθρωπος είναι ένα μαλακισμένο παραδοπιστο καθίκι, που αδιαφορεί κ για τα παιδιά του. Η φάτσα του πάντως είναι και καρικατούρα ταιριάζει μ' αυτά που λέει.
# true label: NOT	 pred_label: OFF	 tweet: @USER πουτανας γιε φίλη τουρκοσπορε φιλοπουστρα να βάλεις δέκα πρόσφυγες στο σπίτι σου να σου γαμανε τη γυναίκα βοδι
# true label: NOT	 pred_label: OFF	 tweet: @USER Από την Αρχαία Αθήνα έως σήμερα, πες μου πότε έχει εκλεγεί από τον όχλο ο Άριστος. Αυτό το κΥνοβολευτικό σύστημα θα το αποτεφρώσουμε και η σκόνη του θα εξανεμιστεί. Να είσαι σίγουρος ότι την ώρα της κρίσης κανένα κομματόσκυλο δε θα προτάξει τα στήθια του...
# true label: NOT	 pred_label: OFF	 tweet: Ωραίο το κονσεπτάκι αλλά γιατί της έστησαν μπροστά από αυτό το βρωμόπανο; #GNTMgr
# true label: NOT	 pred_label: OFF	 tweet: @USER Α καλά είσαι.. Και το χειρότερο όταν τους τα εξηγείς και τους λες κ ηλίθιους παρεξηγούνται
# true label: NOT	 pred_label: OFF	 tweet: Είστε ξεφτίλες! Κάθεστε και γελάτε σαν τους κάφρους για κάτι τόσο σοβαρό που συνέβη στην κοπέλα αυτή..... Λυπάμαι πραγματικά..... Και περισσότερο για τις γυναίκες της παρέας σας.... Ντροπή απλά! Ξεφτίλα! #mesimeri_skai
# true label: NOT	 pred_label: OFF	 tweet: @USER ΡΕ ΞΕΦΤΙΛΑ 126 ΘΆΝΑΤΟΙ ΡΕ ΖΩΟΝ το θέμα σου είναι να κάνουμε κουβεντούλα εδώ; Δεν ειναι κομματικό το θέμα ρε ΒΛΑΚΑ.
# true label: NOT	 pred_label: OFF	 tweet: ΜΕ ΣΗΜΑ ΣΤΗΝ ΚΑΡΔΙΑ ΕΝΑΝ ΠΟΥΣΤΑΡΑ! ΣΤΗΣ ΤΡΟΥΜΠΑΣ ΤΑ ΣΤΕΝΑ Η ΜΑΝΑ ΣΑΣ ΕΠΙΑΣΕ ΔΟΥΛΕΙΑ! ΚΑΙ ΓΑΜΙΟΤΑΝΕ! ΚΑΙ ΞΕΣΚΙΖΟΤΑΝΕ! ΚΑΙ ΕΚΑΝΕ ΠΑΙΔΙΑ Σ' ΟΛΟ ΤΟΝ ΠΕΙΡΑΙΑ! ΕΣΑΣ ΤΑ ΜΠΑΣΤΑΡΔΑ! ΝΑΥΤΗΣ Ο ΜΠΑΜΠΑΣ, ΠΟΥΤΑΝΑ Η ΜΑΜΑ!
# true label: NOT	 pred_label: OFF	 tweet: @USER Επιεικώς ΕΊΣΑΙ ΠΟΛΥ ΓΕΛΟΊΟΣ
# true label: OFF	 pred_label: NOT	 tweet: @USER Το οτι μας λενε ρατσιστες ουτε καν με απασχολει και γραμμενους τους εχω. Χιλιες φορες "ρατσιστης" και "φασιστας" παρα σφαγμενος και κυνηγημενη μειονοτητα στην ιδια μου τη Πατριδα
# true label: NOT	 pred_label: OFF	 tweet: Μεγάλα πουλιά, μαμούνες, μπάμιες... πχιότητα στην ελληνική τιβί #giatinparea
# true label: OFF	 pred_label: NOT	 tweet: @USER Οι ψηφοφόροι του ΣΥΡΙΖΑ ψήφισαν Κουντούρα κ Γεωργουλη(που τον σούταρε η ΝΔ), ανέχτηκαν Καμμενο,Κουίκ,Παπακωστα(που έλεγε κατσαρίδες τους παράνομους μεταναστες).....Ο ΣΥΡΙΖΑ ειναι ενα λαϊκίστικο κομμα, αποτελούμενο απο τυχοδιώκτες. Σαν εσενα.
# true label: NOT	 pred_label: OFF	 tweet: @USER Θέλω να γράψω ποστ με κύριο θέμα "τα fake news δουλεύουν επειδή είσαι ηλίθιος. Καλά, όχι εσύ, ο δίπλα σου. Μέτρα ηλίθιους που καθημερινά ποστάρουν παπαριές" αλλά έχω βαρεθεί το μπλογκ πια και με θρεντ δεν γίνεται.
# true label: NOT	 pred_label: OFF	 tweet: @USER Βρε αρχιψεύταρε, εκτός ότι όλοι οι αριστεροί είστε άχρηστοι γενικώς, δεν βλέπετε καν και τι βάζετε στις δημοσιεύσεις σας και γίνεστε ρόμπα...! #syriza_xeftiles #Ευρωεκλογές2019 #ερχεται_ΠΟΥΤΣΑ
# true label: NOT	 pred_label: OFF	 tweet: @USER ΦΕΡΤΕ ΠΡΕΖΑ ΝΑ ΠΡΕΖΑΡΩ! cc #Αξιωματική_αντιπολίτευση #ΝΔ_ξεφτιλες #σιλα_εισαι_μαλακας #Συντηριτικη_παράταξη
# true label: NOT	 pred_label: OFF	 tweet: @USER Είσαι το Σπερματοζωαριοπου έλειπε από τον Κατσαπλια για να γεννηθεί ένα Μόρφωμα
# true label: NOT	 pred_label: OFF	 tweet: @USER φωνή βοώντος εν τη ερημω είσαι ρε σκωληξ Respect ρε
# true label: NOT	 pred_label: OFF	 tweet: Αν δεν είσαι ένα διεστραμμένο, μισογύνικο, γλοιώδες, παράσιτο της κοινωνίας, τότε δεν έχεις ερωτευτεί. #γιαννακοπουλος_ερωτιαρης
# true label: NOT	 pred_label: OFF	 tweet: Άσε ρε φίλε πήγαινε πουλά αλλού το παραμύθι πέρυσι βάλαμε γκολ στον Βαζελο στο 97 και φωνάζανε όλοι και εσείς οι κομπλεξικοι του βορρά πόσες καθυστερήσεις έπρεπε να κρατήσει;Οπότε αλλού αυτά πουτανες του Ρώσου!
# true label: NOT	 pred_label: OFF	 tweet: @USER ΔΕΝ ΦΡΟΥΡΟΥΝ ΤΟ ΑΙΓΑΙΟ!ΟΙ ΤΟΥΡΚΟΙ ΚΑΝΟΥΝ ΧΙΛΙΑΔΕΣ ΠΑΡΑΒΙΑΣΕΙΣ! ΈΠΡΕΠΕ ΝΑ ΤΟΥΣ ΕΙΧΑΝ ΚΤΥΠΗΣΕΙ!ΑΛΛΑ ΕΙΝΑΙ ΚΟΤΕΣ!ΔΕΝ ΕΠΙΤΕΛΟΥΝ ΣΗΜΕΡΑ ΤΟ ΕΡΓΟ ΤΟΥΣ!ΑΛΛΑ ΕΙΝΑΙ ΣΗΜΕΡΑ ΤΑ ΓΙΟΥΣΟΥΦΑΚΙΑ ΟΙ ΚΟΥΡΙΕΡ ΤΩΝ ΜΟΥΣΟΥΛΜΆΝΩΝ ΛΑΘΡΟΜΕΤΑΝΆΣΤΩΝ!Η ΕΛΛΑΔΑ ΕΙΝΑΙ ΣΚΛΑΒΩΜΈΝΗ ΣΤΟΥΣ ΓΕΡΜΑΝΟΥΣ!
# true label: NOT	 pred_label: OFF	 tweet: #poweroflovegr Ούτε για πίπα δεν κάνεις...
# true label: NOT	 pred_label: OFF	 tweet: Ναι...πες μας Κάτια. Σε ακούμε Χεσμενη σε έχουμε. #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: Και διακοσίω χρονώ θα ξεροχύνω με αυτόν τον τίτλο μωρή πλίζαρ. Το νου σου για προπερ μαςς πιβιπι δις ταιμ μη τα σφαξω όλα. #DiabloIV #DiabloIVgr
# true label: NOT	 pred_label: OFF	 tweet: Γκαγκακη, ατυχές στιγμές τα σχόλια γ την φοιτήτρια. Τι λες μωρή σαβούρα! Διαμορφώνετε ήθος κ συμπεριφορές σε νέα παιδιά τόσα χρόνια κ λες "ατυχές στιγμές. Δε χρειάζεται να μας πείτε τι κάνετε τα βράδυ στα γραφεία με τα αφεντικα σας. Το βλέπουμε. Φύγανε οι βίζιτες από βουκουρεστι
# true label: NOT	 pred_label: OFF	 tweet: @USER Σύρθηκε σε εκλογές και ξεφλούδισε ο κωλος του για να ξεκολλήσει από την καρέκλα. Χρόνια χρειάζεται η χώρα για να επανέλθει στην κανονικότητα. Οι ζημιές είναι ανυπολόγιστες και θα τις πληρώσετε όλοι σας.
# true label: NOT	 pred_label: OFF	 tweet: @USER τόσο κωλοπιλάλα σε έχει πιάσει χριστοφορίδη... σε λίγες μέρες #ερχεται_ΠΟΥΤΣΑ και θα γεμίσει η τρύπα σου κρέας.. μην κάνεις σαν @USER@USER συριζαία drag queen...
# true label: NOT	 pred_label: OFF	 tweet: Σφυγμέμη δεν λες τίποτα η Μαρτίνα! Σαν κωλοτρυπίδα! #GNTMgr
# true label: NOT	 pred_label: OFF	 tweet: Τώρα εδώ που τα λέμε αν βάλεις δίπλα δίπλα το golden pass με την Σουζάνα ούτε που θα την προσέξει κανείς την 1η! Απλά είχε μαλακισμένη συμπεριφορά η Σουζάνα και το έφαγε το κεφάλι της. #gntmgr
# true label: NOT	 pred_label: OFF	 tweet: 40 βαθμοί κ αντί για μουναρα νιώθω κότα σε κλουβί. σταδιαλα.
# true label: NOT	 pred_label: OFF	 tweet: @USER Κάτι τέτοιες πιπες λέτε εσείς οι πουστηδοι, και μου χετε φκιαξει ένα μοραλιτι, σιδερομπετοβεργα μασιφ. Γαμημενοι άντρες
# true label: NOT	 pred_label: OFF	 tweet: @USER Ε είδες που είσαι καθυστερημένος; Χεστηκα για τον Λοβέρδο και τον Γεωργιάδη. Την αλήθεια υπερασπίζομαι και περιμένω στοιχεία. Δεν έχεις.- είσαι απλά ένας έμμισθος υπάλληλος, θα τα πούμε με τα αφεντικά σου σε ένα μήνα στις κάλπες.
# true label: NOT	 pred_label: OFF	 tweet: Και μετά απορεις βρε βλήμα γτ είσαι στο στόχαστρο; #GNTMgr
# true label: NOT	 pred_label: OFF	 tweet: Γεώργιε Δώνη, τσίμπα ένα αρχίδι κ πες κ ένα ευχαριστώ στο κοράκι χτες. Διότι αν είχε, ως όφειλε, δώσει 7-8 λεπτά καθυστερήσεων, θα είχες τσιμπήσει το πλήρες σετ, 2 όρχεις κ την πούτσα. Μουνόπανο. #paokpao
# true label: NOT	 pred_label: OFF	 tweet: Κόνσεπτ κλεμμένο από Εγκλήματα, η τσόντα της Κορίνας #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: @USER Σε περίπτωση που σας διαφεύγει ΨΗΦΙΣΤΗΚΕ.... δεν διορίστηκε σαν τον πατέρα η την ετεροθαλή αδερφή του Παππα
# true label: OFF	 pred_label: NOT	 tweet: @USER Καλητερα να φαίνεσαι φασίστας και ρατσιστής παρά να γίνετε αυτο που γίνετε τωρα στην Ελλάδα
# true label: NOT	 pred_label: OFF	 tweet: Μαρθα πως νιώθεις που βλέπεις μαζί πατέρα και κόρη; Άντε και εσύ μαλακισμενη #gynaikaxwrisonoma
# true label: NOT	 pred_label: OFF	 tweet: @USER Αυτα που χω δει εγω δεν αξιζουν παντως.. Εχω δει πολυ καλυτερα. Εν τω μεταξυ παιζει να εχω λαβει περισσοτερα βυζια κωλους κ μουνια απ οτι ντικ πικς..
# true label: NOT	 pred_label: OFF	 tweet: @USER Ε βούλωσε επιτέλους την τρύπα που γενάει κοτσάνες ρε ΝΟΥΜΕΡΟ! Μιλάς ΕΣΥ ρε ΑΡΟΥΡΑΙΑΕ για χουντογόνους; Και εμείς ξέρουμε γοια τις 50άδες μετακλητούς του Κούλη, δεν φτάσαμε ποτέ στην ξεφτίλα αυτής της παπαροεπιχειρηματολογίας- υπήρχαν παντα οι ΜΠΑΖΕΣ ΣΑΣ.
# true label: OFF	 pred_label: NOT	 tweet: @USER Και ο Δήμαρχος Κω ακροδεξιός φασίστας Δημήτρη;
# true label: NOT	 pred_label: OFF	 tweet: @USER Ντροπή ρε φίλε να αναπαράγεις εδώ μέσα τις ψευτιές fake news του ρουφιανάκου που επί 3 χρόνια έβριζε και συκοφαντούσε χυδαία και επί προσωπικού, που ήταν κώλος και βρακί με ΝΔ - ΠΑΣΟΚ στον ΠΙΣ και που τις βρωμιές του τις ανπαρήγαγε copy paste το σάϊτ της ΧΑ ... εκτίθεσαι, σβήστο.
# true label: NOT	 pred_label: OFF	 tweet: Τσισμιλη είσαι γελοία φτιάξε κανα φρικασέ με τον Ζαν Λουί Καψάλα και άσε τις κι καλά πολιτικές συνεντεύξεις Τσουράπω
# true label: NOT	 pred_label: OFF	 tweet: Είσαι Κλανεκοειδές ή αυθεντικό ;
# true label: NOT	 pred_label: OFF	 tweet: Μια κοτα στρουμπουλή μια ομορφη πουλαδα ,ήξερα κυρια δουρου οτι μας εκαψες την γούνα να παραδέχεσαι ομως οτι είσαι κοτα δημοσια ,θελει Θάρρος και θράσος οπως θα έλεγε και ο Γούναρης που εγραψε το ασμα ..
# true label: NOT	 pred_label: OFF	 tweet: @USER Τα Γιαννιτσά ρε μλκ, που οποίος είναι από κει θέλει να φύγει, θα τρελαθουμε
# true label: NOT	 pred_label: OFF	 tweet: Ετσι θα σας παει καριολακια #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: Αμανατιδου : "Πουλο τωρα" #Gntmgr
# true label: NOT	 pred_label: OFF	 tweet: Ο Παύλος έχει κατι βάρβαρο απολίτιστο ωμο επίσης είναι απόλυτος και ξεροκέφαλος αλλά δεν είναι κωλοπαιδαρας και αυτό πρέπει να το συνυπολογίσουμε @USER #PowerofLoveGR
# true label: NOT	 pred_label: OFF	 tweet: @USER μαλακα μου εισαι οχι απλα βλακας μπετοβλακας...
# true label: NOT	 pred_label: OFF	 tweet: @USER μην μας το παιζεις πονοψυχη,κρυφορατσιστρια του κερατα. μεταξυ σας αυτα να τα λετε,δημοσιως δεν πιανουν. Φασισταρια ,ρατσιστες,πατριδοκαπηλα ανιστορητα υποκοσμικα ανθρωπαρια η δεξια/ναζι
# true label: NOT	 pred_label: OFF	 tweet: Μίλτο μαλακίζεσαι σαν τον Ζαχάρωφ #kokkinopotami
# true label: NOT	 pred_label: OFF	 tweet: Εν τω μεταξύ παρατήρησα ότι ούτε εδώ μέσα μπορώ να κρατήσω κακία και ας είμαστε άγνωστοι,που θα μου ήταν και ευκολότερο. Αμα είσαι σκατοχαρακτηρας....
# true label: NOT	 pred_label: OFF	 tweet: #ηρθε_και_ηταν_μεγαλη #ερχεται_ΠΟΥΤΣΑ και στις 30/6 Κατουρλή, δεν βρέχει. Σας φτύνουν οι πολλοί.
# true label: NOT	 pred_label: OFF	 tweet: @USER Γιωργοοοοοοοοοοοοοοοοοοοο, Πού είσαι ρε μαλακιστήρι; Ήρθε η πούτσα αλλά η μεγαλύτερη θα έρθει σε ένα μήνα.
# true label: NOT	 pred_label: OFF	 tweet: Αφου μωρη Τσουζανα εισαι ΑΧΡΗΣΤΗ ! Σκασε τωρα και μπουκωνε #GNTMgr
# true label: OFF	 pred_label: NOT	 tweet: Εχω χασει 5 κιλα ρε μαλακες τοσες ωρες με το μπρος πισω στον καναπε! Ναι οχι ναι παμε ναι οχι Οχιιιιιιι #Tsitsipas
# true label: OFF	 pred_label: NOT	 tweet: Και μην ξεσηκωθεί τωρα ολες οι φιλόζωες και κράζετε για τις κότες και τις φραγκόκοτες δεν Παθαίνουν τίποτα. Όλες από χωριό είστε και ξέρετε! #gntmgr
# true label: OFF	 pred_label: NOT	 tweet: @USER Σε κάποια χρόνια θα μαλώνετε σε φανάρι της Συγγρού και θα σου πει άντε μωρη γιαγια μου θες και αμάξι
# true label: NOT	 pred_label: OFF	 tweet: Ξεκίνησαν να έχουν απαιτήσεις για Χαλάλ φαγητό, μετά για απαγόρευση χοιρινού κ αλκοόλ, σε λίγο να μην χτυπάνε οι καμπάνες, να μην κυκλοφορούν ξεσκέπαστες οι γυναίκες, στο τέλος θα φτιάξουν ένα νέο Αφγανιστάν στην Ευρώπη.ΡΕ ΆΝΤΕ ΚΑΙ Γ@USER..ΞΎΠΝΑΤΕ ΈΛΛΗΝΕΣ ΠΡΙΝ ΝΑ ΕΊΝΑΙ ΑΡΓΆ!
# true label: NOT	 pred_label: OFF	 tweet: - εγώ αργά και βασανιστικά κατεβάζω το εσώρουχο σου ... - ρε, βλαμμένο εισαι; Τελείωνε με τα απλωμένα, ψιχαλιζει ! – χαζή
# true label: NOT	 pred_label: OFF	 tweet: Έγκυες γυναίκες πρέπει να τρώνε στη μάπα τον καπνό του κάθε ηλίθιου, άνθρωποι με αναπνευστικά προβλήματα το ίδιο, άτομα με πρόβλημα στα μάτια επίσης, παιδιά τρώνε μέσα σε σύννεφα καπνού αλλά είναι φασισμός η απαγόρευση του καπνίσματος. Γενικά πάτε με τα σωστά σας;
# true label: OFF	 pred_label: NOT	 tweet: Εντάξει, αυτή η χώρα θα πάει στο διάολο. Εμείς τι φταίμε; #Εκλογες_2019
# true label: NOT	 pred_label: OFF	 tweet: #survivorgr Α Και 60 φορές και με διαφορετικούς... Ε είσαι πολύ τσοκαρο κορίτσι μού
# true label: OFF	 pred_label: NOT	 tweet: @USER μιλαμε για την ΞΕΦΤΙΛΑ
# true label: NOT	 pred_label: OFF	 tweet: Το Χωνί μάλλον είσαι εσυ @USER , εγώ να ξέρεις δεν υιοθετώ σεξουαλικα υποννουμενα
# 0.6550632911392406	0.8553719008264463	0.7419354838709679	0.9067357512953368
